# %% [markdown]
# # Lecture 8

# %% [markdown]
# Friday, September 11, 2026

# %%
# Example
T = 100 / (1-0.01)
print(T)

T = 100 / (1+0.01)
print(T)
# Out:
# 101.01010101010101
# 99.00990099009901

# %%
# Example
R = (102 - 100) / 98

print(R)
# Out:
# 0.02040816326530612

# %% [markdown]
# ## Sources of Errors

# %% [markdown]
# 1) Modeling Errors: hypothesis and simplification (not in scope)
# 2) Mathematical Approx. Error: when using an expression to approximate another
# 3) Roundoff Error: due to the finite precision of number representation

# %% [markdown]
# Example
# $f'(a) = lim_{x \to 0}\frac{f(a+h)-f(a)}{h}$

# %% [markdown]
# ## Algorithm Properties

# %% [markdown]
# - Accuracy: must have good accuracy
# - Efficiency: how long it takes
# - Stability/Robustness: work under situations
