# %% [markdown]
# # Lists

# %%
my_list = ['item 0', 1, 2.0, 'end']
# You can have a bunch of stuff in it

for i in my_list:
    print(i)
# Out:
# item 0
# 1
# 2.0
# end

# %%
# Accessing items in the list. Use index
