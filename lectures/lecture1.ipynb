# %% [markdown]
# # Lecture 1: Monday August 24, 2026

# %%
# Do a bunch of brain dead python
x = 1 + 4  / 2 * 5
print(x)

# Flooring
y = 5 // -2
print(y)

# Parentheses
z = 4 - (2 * 3) ** 2
print(z)

# Round off errors in adding floats
# Turn stuff into integer, string, float, etc.

something = ((4-1) * 2**5 - abs(3**4 - 4**3) + 5**0) / (100/5 * 2)
print(something)
# Out:
# 11.0
# -3
# -32
# 2.0

# %%
# Exercise 2
a = 2
b = 3
print(a, b)

# dummy variable
c = a

a = b
b = c
print(a, b)

a, b = b, a

print(a, b)
# Out:
# 2 3
# 3 2
# 2 3

# %%
# Exercise 3
a = 1
for i in range(3):
    a = 2*a + 1

print(a)
# Out:
# 15
