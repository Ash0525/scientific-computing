# %%
# Recreating The Bisection Method for solving f(x)

# Let f(x) equal x^2 - 2
def f(x):
    return x**2 - 2

def bisection_method(f, a, b, tolerance):
    fa = f(a)
    fb = f(b)
    c = (a + b) / 2

    if (fa * fb > 0):
        raise ValueError(f"f(a)={fa} and f(b)={fb} must have different signs!")
    
    while (b - a > tolerance):
        c = (a + b) / 2
        fc = f(c)

        if fc == 0:
            return c
        
        elif fa * fc < 0:
            b = c
            fb = fc
        
        else:
            a = c
            fa = fc
    
    return (a + b) / 2

root = bisection_method(f, 1, 2, 1e-6)
print(f"Roots of the function f: {root}")
# Out:
# Roots of the function f: 1.4142136573791504
