# %% [markdown]
# # Question 1

# %%
a = 1
b = 2
a = a + b
b = b + a
print(b)
# Out:
# 5

# %% [markdown]
# # Question 2

# %%
total = 0

for i in range(1, 51):
    total += 2 * i - 1

print(total)
# Out:
# 2500

# %% [markdown]
# # Question 3

# %%
n = 1

while (n**3 + n**2 + n) < 10000:
    n += 1

print(n)
# Out:
# 22

# %% [markdown]
# # Question 4

# %%
# Find if true

if 1 == (1 + 2**-54):
    print(f"Yes, they are equal!")
else:
    print(f"No they are not equal")
# Out:
# Yes, they are equal!

# %% [markdown]
# # Question 5

# %%
y = lambda x: abs(x**3 - 3*x)

print(y(-10))
print(y(10))
# Out:
# 970
# 970

# %% [markdown]
# # Question 6

# %%
def delta(x):
    if (x < 0):
        return 0
    elif (x > 0):
        return 1
    else:
        return -1

print(delta(1000))
print(delta(-123))
# Out:
# 1
# 0
