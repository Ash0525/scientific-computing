# %% [markdown]
# # Chapter 1 Exercises

# %% [markdown]
# ## Exercise 1.7

# %%
total1 = 0
for m in range(1, 21):
    for n in range(1, 21):
        # each multiplication happens in here
        # bm = bm - Gm,nbn
        total1 += 1

print(total1)
# Out:
# 400

# %%
total2 = 0
for m in range(1, 21):
    for n in range(m, 21):
        # each multiplication happens in here
        # bm = bm - Gm,nbn
        total2 += 1

print(total2)
# Out:
# 210
