# %% [markdown]
# # Question 1

# %%
a = 1
b = 2
a = a + b
b = b + a

print(b)
# Out:
# 5

# %% [markdown]
# # Question 2

# %%
total = 0
for i in range(1, 51):
    total += 2*i - 1

print(total)
# Out:
# 2500

# %% [markdown]
# # Question 3

# %%
n = 1
while (n**3 + n**2 + n) < 10000:
    n += 1

print(n)
# Out:
# 22

# %% [markdown]
# # Question 4

# %%
# Super small, basically 0
if 1 == (1 + 2**-54):
    print("They are the same!")
else:
    print("Different")
# Out:
# They are the same!

# %% [markdown]
# # Question 5

# %%
y = lambda x: abs(x**3 + 3*x)

print(y(0))
print(y(-3))
print(y(3))
# Out:
# 0
# 36
# 36

# %% [markdown]
# # Question 6

# %%
def unit_step(x):
    if (x < 0):
        return 0
    elif (x > 0):
        return 1
    else:
        return -1
    
print(unit_step(0))
print(unit_step(-10000))
print(unit_step(231))
# Out:
# -1
# 0
# 1
