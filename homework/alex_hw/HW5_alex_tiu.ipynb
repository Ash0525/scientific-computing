# %% [markdown]
# # Problem 3.1

# %%
# Chapter 3 problems

# Let f(x) = sin(x) and a = pi / 4
# Let T = f'(x)
# Let A = (f(a) - f(a-h)) / h
import numpy as np
import matplotlib.pyplot as plt

# The idea is that as h gets smaller, An is supposed to become the derivative
# For i in range 1 to 53, exclusive, take 2 to the -ith power
h = np.array([2**(-i) for i in range(1, 53)])
a = np.pi / 4
eDP = 2**-52

A = (np.sin(a) - np.sin(a - h)) / h

# Let f(a) be the function evaluated at a
f = np.sin(a)

# Let T(a) be the first derivative of f
T = np.cos(a)   # T does not depend on h

# Let T2(a) be the second derivative of f
T2 = -(np.sin(a))

# %% [markdown]
# ## Part 1

# %%
# The absolute relative error r = |A - T| / |T|

# Find the absolute relative error
r = np.abs(A - T) / np.abs(T)

# Define c1 and c2 (from book)
c1 = np.abs(T2 / (2 * T))
c2 = np.abs((f * eDP) / T)

# Define upper bound R
R = c1 * h + c2 * (1 / h)

print(f"For each value of h, calculate the error, r:\n{r}")
print(f"The upper bound R:\n{R}")
print(c1)
print(c2)
# Out:
# For each value of h, calculate the error, r:
# [2.03685953e-01 1.13966150e-01 5.98165292e-02 3.05889143e-02
#  1.54609760e-02 7.77165145e-03 3.89605764e-03 1.95057939e-03
#  9.75926407e-04 4.88122266e-04 2.44100884e-04 1.22060378e-04
#  6.10326730e-05 3.05169578e-05 1.52586385e-05 7.62935920e-06
#  3.81470927e-06 1.90735858e-06 9.53744970e-07 4.76958746e-07
#  2.38730270e-07 1.19862987e-07 6.05939808e-08 3.03009335e-08
#  1.97642213e-08 1.44958653e-08 2.50325774e-08 2.50325774e-08
#  6.71794259e-08 6.71794259e-08 6.71794259e-08 4.04354214e-07
#  1.07870379e-06 1.07870379e-06 1.07870379e-06 1.18682970e-05
#  1.07870379e-06 2.26578902e-05 6.58162631e-05 6.58162631e-05
#  2.38449755e-04 5.83716738e-04 1.27425070e-03 2.65531864e-03
#  5.41745450e-03 5.41745450e-03 1.64659980e-02 1.64659980e-02
#  6.06601718e-02 6.06601718e-02 6.06601718e-02 4.14213562e-01]
# The upper bound R:
# [2.50000000e-01 1.25000000e-01 6.25000000e-02 3.12500000e-02
#  1.56250000e-02 7.81250000e-03 3.90625000e-03 1.95312500e-03
#  9.76562500e-04 4.88281250e-04 2.44140625e-04 1.22070313e-04
#  6.10351581e-05 3.05175818e-05 1.52587963e-05 7.62940908e-06
#  3.81472637e-06 1.90740684e-06 9.53790732e-07 4.77069989e-07
#  2.38884240e-07 1.20140612e-07 6.14672899e-08 3.35276127e-08
#  2.23517418e-08 2.23517418e-08 3.35276127e-08 6.14672899e-08
#  1.20140612e-07 2.38884240e-07 4.77069989e-07 9.53790732e-07
#  1.90740684e-06 3.81472637e-06 7.62940908e-06 1.52587963e-05
#  3.05175818e-05 6.10351581e-05 1.22070313e-04 2.44140625e-04
#  4.88281250e-04 9.76562500e-04 1.95312500e-03 3.90625000e-03
#  7.81250000e-03 1.56250000e-02 3.12500000e-02 6.25000000e-02
#  1.25000000e-01 2.50000000e-01 5.00000000e-01 1.00000000e+00]
# 0.5
# 2.220446049250313e-16

# %% [markdown]
# ## Part 2

# %%
# Plot the error (r versus h) and upper bound (R versus h)

plt.loglog(h, r,'bo')
plt.loglog(h, R, 'k')
plt.xlabel('h')
plt.ylabel('Relative Error')
plt.title('Relative Error and Upper Bound vs. Step Size')
# Out:
# Text(0.5, 1.0, 'Relative Error and Upper Bound vs. Step Size')

# %% [markdown]
# ## Part 3

# %% [markdown]
# As h decreases from its largest value, the relative error r decreases until it reaches a minimum around the 10^-8 to 10^-7 range. After that point, the error begins to increase again as h becomes even smaller. This indicates that there is an optimal range of h where the backward difference approximation is the most accurate.
#
# The upper bound R follows the same general trend as the relative error. It decreases at first, reaches a minimum, and then increases for very small values of h. Throughout the graph, R stays above the measured relative error r, which is consistent with it being an upper bound on the error.

# %% [markdown]
# ## Part 4

# %% [markdown]
# This behavior makes sense because there are two different sources of error. When h is too large, the backward difference formula is not a close enough approximation of the derivative, so the approximation error is large. As h decreases, this error becomes smaller and the approximation becomes more accurate.
#
# However, when h becomes extremely small, f(a) and f(a−h) are nearly equal. Subtracting these values causes significant-digit cancellation, and dividing the resulting roundoff error by a very small h makes the result close to 1. Therefore, the error is smallest at an intermediate value of h, where the approximation error and roundoff error are balanced.

# %% [markdown]
# ## Part 5

# %% [markdown]
# Recall that R is defined as below:

# %% [markdown]
# $$
# R = c_1 h + \frac{c_2}{h}
# $$

# %% [markdown]
# To minimize, let the derivative of R equal 0:

# %% [markdown]
# $$
# \frac{dR}{dh} = c_1 - \frac{c_2}{h^2} = 0
# $$

# %% [markdown]
# Set $\frac{dR}{dh}=0$ and solve for $h$. We get $h$ to be $2.107*10^-8$

# %% [markdown]
# # Problem 3.4

# %% [markdown]
# ## Part 1

# %%
# We must begin with V0 = ln(11/10)
import numpy as np

v0 = np.log(11/10)

# List of k
k_values = range(1, 21)

# Put Vk in here
vk =[]

# Initialize temp to hold v0
temp = v0

for num in k_values:
    temp = (1 / num) - 10 * temp
    vk.append(temp)

for k, V in enumerate(vk):
    print(f"k={k+1:2d} : V={V:14.9f} : V/10^k={(V / 10**k):14.9e}")
# Out:
# k= 1 : V=   0.046898202 : V/10^k=4.689820196e-02
# k= 2 : V=   0.031017980 : V/10^k=3.101798043e-03
# k= 3 : V=   0.023153529 : V/10^k=2.315352901e-04
# k= 4 : V=   0.018464710 : V/10^k=1.846470992e-05
# k= 5 : V=   0.015352901 : V/10^k=1.535290084e-06
# k= 6 : V=   0.013137658 : V/10^k=1.313765827e-07
# k= 7 : V=   0.011480560 : V/10^k=1.148056018e-08
# k= 8 : V=   0.010194398 : V/10^k=1.019439825e-09
# k= 9 : V=   0.009167129 : V/10^k=9.167128613e-11
# k=10 : V=   0.008328714 : V/10^k=8.328713865e-12
# k=11 : V=   0.007621952 : V/10^k=7.621952257e-13
# k=12 : V=   0.007113811 : V/10^k=7.113810768e-14
# k=13 : V=   0.005784969 : V/10^k=5.784969245e-15
# k=14 : V=   0.013578879 : V/10^k=1.357887898e-15
# k=15 : V=  -0.069122123 : V/10^k=-6.912212311e-16
# k=16 : V=   0.753721231 : V/10^k=7.537212311e-16
# k=17 : V=  -7.478388781 : V/10^k=-7.478388781e-16
# k=18 : V=  74.839443369 : V/10^k=7.483944337e-16
# k=19 : V=-748.341802108 : V/10^k=-7.483418021e-16
# k=20 : V=7483.468021085 : V/10^k=7.483468021e-16

# %% [markdown]
# ## Part 2

# %% [markdown]
# As k increases, the computed values decrease. Once the computed value reaches k=14, the computed value begins to increase and alternate in sign.

# %% [markdown]
# ## Part 3

# %% [markdown]
# Let $\hat{V}_k$ represent the computed values with error. Let $e_k$ represent the error. We know from error propagation that error is added to the original, so:

# %% [markdown]
# $$
# \hat{V_k} = V_k + e_k
# $$
# $$
# e_k = \hat{V_k} - V_k
# $$

# %% [markdown]
# Now we can plug in the equations representing $\hat{V}_k$ and $V_k$

# %% [markdown]
# $$
# e_k=\hat{V}_k-V_k
# $$
#
# $$
# =\left(\frac{1}{k}-10\hat{V}_{k-1}\right)-\left(\frac{1}{k}-10V_{k-1}\right)
# $$
#
# $$
# =-10\left(\hat{V}_{k-1}-V_{k-1}\right)=-10e_{k-1}
# $$

# %% [markdown]
# After some manipulation, you can write the error generally:

# %% [markdown]
# $$
# e_1=-10e_0,\quad e_2=(-10)^2e_0,\quad e_3=(-10)^3e_0
# $$
#
# $$
# \therefore\ e_k=(-10)^k e_0
# $$

# %% [markdown]
# As k increases, the error is multiplied by -10 at every step. Thus, the sign of the error alternates while the magnitude increases by a factor of 10

# %% [markdown]
# ## Part 4

# %%
# Re-run the program for e=0.17, 0.0023, and 0.000036

e1 = 0.17
e2 = 0.0023
e3 = 0.000036

v0e1 = v0 + e1
v0e2 = v0 + e2
v0e3 = v0 + e3

# List of k
k = [i for i in range(1,21)]

# Put Vk in here
vke1 =[]

# Initialize temp
temp = v0e1

print(f"Vk when error={e1}\n\n")
for num in k:
    temp = (1 / num) - 10 * temp
    vke1.append(temp)

for k, V in enumerate(vke1, start=1):
    print(f"k={k:2d} : V={V:14.9f} : V/10^k={(V / 10**k):14.9e}")

# Put Vk in here
vke2 =[]

# Initialize temp
temp = v0e2

print(f"Vk when error={e2}\n\n")
for num in k_values:
    temp = (1 / num) - 10 * temp
    vke2.append(temp)

for k, V in enumerate(vke2, start=1):
    print(f"k={k:2d} : V={V:14.9f} : V/10^k={(V / 10**k):14.9e}")

# Put Vk in here
vke3 =[]

# Initialize temp
temp = v0e3

print(f"Vk when error={e3}\n\n")
for num in k_values:
    temp = (1 / num) - 10 * temp
    vke3.append(temp)

for k, V in enumerate(vke3, start=1):
    print(f"k={k:2d} : V={V:14.9f} : V/10^k={(V / 10**k):14.9e}")
# Out:
# Vk when error=0.17
#
#
# k= 1 : V=  -1.653101798 : V/10^k=-1.653101798e-01
# k= 2 : V=  17.031017980 : V/10^k=1.703101798e-01
# k= 3 : V=-169.976846471 : V/10^k=-1.699768465e-01
# k= 4 : V=1700.018464710 : V/10^k=1.700018465e-01
# k= 5 : V=-16999.984647099 : V/10^k=-1.699998465e-01
# k= 6 : V=170000.013137658 : V/10^k=1.700000131e-01
# k= 7 : V=-1699999.988519439 : V/10^k=-1.699999989e-01
# k= 8 : V=17000000.010194395 : V/10^k=1.700000001e-01
# k= 9 : V=-169999999.990832835 : V/10^k=-1.700000000e-01
# k=10 : V=1700000000.008328199 : V/10^k=1.700000000e-01
# k=11 : V=-16999999999.992372513 : V/10^k=-1.700000000e-01
# k=12 : V=170000000000.007080078 : V/10^k=1.700000000e-01
# k=13 : V=-1699999999999.993896484 : V/10^k=-1.700000000e-01
# k=14 : V=17000000000000.011718750 : V/10^k=1.700000000e-01
# k=15 : V=-170000000000000.062500000 : V/10^k=-1.700000000e-01
# k=16 : V=1700000000000000.500000000 : V/10^k=1.700000000e-01
# k=17 : V=-17000000000000004.000000000 : V/10^k=-1.700000000e-01
# k=18 : V=170000000000000032.000000000 : V/10^k=1.700000000e-01
# k=19 : V=-1700000000000000256.000000000 : V/10^k=-1.700000000e-01
# k=20 : V=17000000000000002048.000000000 : V/10^k=1.700000000e-01
# Vk when error=0.0023
#
#
# k= 1 : V=   0.023898202 : V/10^k=2.389820196e-03
# k= 2 : V=   0.261017980 : V/10^k=2.610179804e-03
# k= 3 : V=  -2.276846471 : V/10^k=-2.276846471e-03
# k= 4 : V=  23.018464710 : V/10^k=2.301846471e-03
# k= 5 : V=-229.984647099 : V/10^k=-2.299846471e-03
# k= 6 : V=2300.013137658 : V/10^k=2.300013138e-03
# k= 7 : V=-22999.988519440 : V/10^k=-2.299998852e-03
# k= 8 : V=230000.010194398 : V/10^k=2.300000102e-03
# k= 9 : V=-2299999.990832873 : V/10^k=-2.299999991e-03
# k=10 : V=23000000.008328732 : V/10^k=2.300000001e-03
# k=11 : V=-229999999.992378235 : V/10^k=-2.300000000e-03
# k=12 : V=2300000000.007115841 : V/10^k=2.300000000e-03
# k=13 : V=-22999999999.994235992 : V/10^k=-2.300000000e-03
# k=14 : V=230000000000.013793945 : V/10^k=2.300000000e-03
# k=15 : V=-2300000000000.070800781 : V/10^k=-2.300000000e-03
# k=16 : V=23000000000000.769531250 : V/10^k=2.300000000e-03
# k=17 : V=-230000000000007.625000000 : V/10^k=-2.300000000e-03
# k=18 : V=2300000000000076.000000000 : V/10^k=2.300000000e-03
# k=19 : V=-23000000000000760.000000000 : V/10^k=-2.300000000e-03
# k=20 : V=230000000000007616.000000000 : V/10^k=2.300000000e-03
# Vk when error=3.6e-05
#
#
# k= 1 : V=   0.046538202 : V/10^k=4.653820196e-03
# k= 2 : V=   0.034617980 : V/10^k=3.461798043e-04
# k= 3 : V=  -0.012846471 : V/10^k=-1.284647099e-05
# k= 4 : V=   0.378464710 : V/10^k=3.784647099e-05
# k= 5 : V=  -3.584647099 : V/10^k=-3.584647099e-05
# k= 6 : V=  36.013137658 : V/10^k=3.601313766e-05
# k= 7 : V=-359.988519440 : V/10^k=-3.599885194e-05
# k= 8 : V=3600.010194397 : V/10^k=3.600010194e-05
# k= 9 : V=-35999.990832863 : V/10^k=-3.599999083e-05
# k=10 : V=360000.008328630 : V/10^k=3.600000083e-05
# k=11 : V=-3599999.992377206 : V/10^k=-3.599999992e-05
# k=12 : V=36000000.007105395 : V/10^k=3.600000001e-05
# k=13 : V=-359999999.994130909 : V/10^k=-3.600000000e-05
# k=14 : V=3600000000.012737751 : V/10^k=3.600000000e-05
# k=15 : V=-36000000000.060714722 : V/10^k=-3.600000000e-05
# k=16 : V=360000000000.669677734 : V/10^k=3.600000000e-05
# k=17 : V=-3600000000006.638183594 : V/10^k=-3.600000000e-05
# k=18 : V=36000000000066.437500000 : V/10^k=3.600000000e-05
# k=19 : V=-360000000000664.312500000 : V/10^k=-3.600000000e-05
# k=20 : V=3600000000006643.000000000 : V/10^k=3.600000000e-05

# %% [markdown]
# When e=0.17, $|\frac{V_k}{10^k}|$ approaches 0.17
# When e=0.0023, $|\frac{V_k}{10^k}|$ approaches 0.0023
# When e=0.000036, $|\frac{V_k}{10^k}|$ approaches 0.000036
